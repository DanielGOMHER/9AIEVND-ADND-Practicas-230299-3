# %% [markdown]
# # Un recorrido visual e informativo – DonorsChoose
#
# ## Ciencia de Datos para el Bien: DonorsChoose
#
# **DonorsChoose** es una organización sin fines de lucro con sede en Estados Unidos que permite a las personas donar directamente a proyectos de aulas de escuelas públicas. Hasta enero de 2018, se habían financiado **1 millón de proyectos** a través de DonorsChoose.org. En el **77 % de las escuelas públicas de Estados Unidos**, al menos un proyecto ha solicitado al menos un proyecto en DonorsChoose.org.
#
# DonorsChoose ha compartido un conjunto de datos completo que incluye todos los proyectos históricos, los recursos relacionados y los metadatos de docentes, escuelas, donantes y donaciones. Estos datos pueden utilizarse para descubrir patrones ocultos y desarrollar soluciones que permitan a DonorsChoose.org crear campañas de correo electrónico dirigidas, recomendando solicitudes específicas de aulas a donantes que ya han contribuido anteriormente.
#
# En este cuaderno (*Notebook*) se realiza un análisis y una exploración detallada del conjunto de datos compartido. Además de proporcionar información relevante sobre los datos de DonorsChoose, también sirve como un tutorial para realizar **análisis de datos**, **análisis exploratorio de datos (EDA)** y **visualización de datos**.
#
# ---
#
# # Contenido
#
# ## 1. Preparación del conjunto de datos
#
# ## 2. Exploración de los donantes
# - **2.1** Panorama general de los donantes.
# - **2.2** Donantes por estado.
# - **2.3** Estados con la mayor proporción de donantes respecto a su población.
# - **2.4** Visualización de la ubicación de los donantes.
#   - **2.4.1** Ubicación de los donantes en California.
#   - **2.4.2** Ubicación de los donantes en Florida.
#   - **2.4.3** Ubicación de los donantes en Nueva York.
#   - **2.4.4** Ubicación de los donantes en Texas.
# - **2.5** Distribución geográfica de los donantes.
# - **2.6** Comparación entre donantes que son docentes y quienes no lo son por estado.
#
# ## 3. Exploración de las donaciones
# - **3.1** Panorama general de las donaciones.
# - **3.2** Proyectos y sus donaciones.
#   - **3.2.1** Proyectos con el mayor número de donantes.
#   - **3.2.2** Proyectos que recibieron el mayor monto total financiado.
#   - **3.2.3** Proyectos con el mayor monto promedio por donante.
#   - **3.2.4** Proyectos con la donación individual más alta.
# - **3.3** Donantes y sus donaciones.
#   - **3.3.1** Donantes con el mayor número de donaciones.
#   - **3.3.2** Donantes que aportaron el mayor monto total.
#   - **3.3.3** Donantes con el mayor promedio por donación.
#   - **3.3.4** Donantes que realizaron la donación individual más alta.
# - **3.4** Montos de donación por año, mes, día y hora.
# - **3.5** Donaciones opcionales y donaciones realizadas por docentes.
#   - **3.5.1** Número y promedio de las donaciones opcionales.
#   - **3.5.2** Número y promedio de las donaciones realizadas por docentes.
# - **3.6** Estado que recibió el mayor monto de donaciones.
# - **3.7** Estado con el mayor promedio de donaciones.
# - **3.8** Total de donaciones recibidas por estado.
# - **3.9** Evolución de las donaciones en California.
#
# ## 4. Exploración de los docentes
# - **4.1** Panorama general de los docentes.
# - **4.2** Primeros docentes registrados en DonorsChoose.
# - **4.3** Crecimiento del número de docentes a lo largo de los años.
# - **4.4** Distribución de los prefijos utilizados por los docentes.
# - **4.5** Serie temporal de los primeros proyectos publicados por los docentes.
#
# ## 5. Exploración de las escuelas
# - **5.1** Panorama general de las escuelas.
# - **5.2** Tipos de escuelas según su zona metropolitana (incluyendo los principales estados y ciudades).
# - **5.3** Distribución del porcentaje de estudiantes que reciben almuerzo gratuito.
# - **5.4** Tipos de escuelas con mayor representación.
#
# ## 6. Exploración de los recursos
# - **6.1** Panorama general de los recursos.
# - **6.2** Artículos más populares en DonorsChoose.
# - **6.3** Artículos más costosos.
# - **6.4** Proveedores más populares y el costo promedio asociado.
#
# ## 7. Exploración de los proyectos
# - **7.1** Panorama general de los proyectos.
# - **7.2** Categorías, subcategorías y categorías de recursos más frecuentes.
# - **7.3** Tipo y estado de los proyectos.
# - **7.4** Fecha de publicación y fecha de financiamiento.
# - **7.5** Trimestre de publicación y de financiamiento.
# - **7.6** Mes en el que se publican más proyectos.
# - **7.7** Tendencia del número de proyectos a lo largo del tiempo.
# - **7.8** Año y mes con el mayor costo de los proyectos.
# - **7.9** Año y nivel educativo con el mayor costo de proyectos.
# - **7.10** Nivel educativo y categoría de recursos con el mayor costo.
# - **7.11** Estado de los proyectos por año.
# - **7.12** Duración de los proyectos financiados con éxito.
# - **7.13** Estado de los proyectos según el estado del país.
# - **7.14** Costo promedio de los proyectos según el tipo de zona metropolitana y la categoría de recursos.
# - **7.15** Costo promedio de los proyectos según el tipo de zona metropolitana y el nivel educativo.
#
# ## 8. Análisis de texto de los proyectos
# - **8.1** Limpieza del texto.
# - **8.2** Análisis mediante el modelo **Bag of Words**.
#   - **8.2.1** Palabras y n-gramas más utilizados por los docentes.
#   - **8.2.2** Palabras y n-gramas más utilizados por estado.
#   - **8.2.3** Contexto de la frase *"My Students Are..."* ("Mis estudiantes son...").
#   - **8.2.4** Contexto de la frase *"My Students Need..."* ("Mis estudiantes necesitan...").
#   - **8.2.5** Palabras clave más frecuentes en los títulos de los proyectos.
#
# ## 9. Comprensión y comparación de las características de los proyectos
# - **9.1** Comparación entre proyectos expirados y proyectos financiados con éxito.
# - **9.2** Comparación entre proyectos con períodos de financiamiento cortos y largos.
# - **9.3** Comparación entre proyectos con un solo donante y aquellos con múltiples donantes.
#
# ---
#
# # 1. Preparación del conjunto de datos
#
# Importemos las bibliotecas necesarias y carguemos el conjunto de datos.

# %%
from plotly.offline import init_notebook_mode, iplot
from wordcloud import WordCloud
import plotly.graph_objs as go
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.io as pio
from plotly import tools
from datetime import date
import pandas as pd
import numpy as np 
import seaborn as sns
import random 
import warnings
import operator
warnings.filterwarnings("ignore")
init_notebook_mode(connected=True)

path = "Datasets/"
donors_df = pd.read_csv(path+"Donors.csv")
donations_df = pd.read_csv(path+"Donations.csv")
teachers_df = pd.read_csv(path+"Teachers.csv")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.0.min"</script>

# %% [markdown]
# ## <a id="2">2. Exploración de los Donantes</a>
#
# El conjunto de datos de **donantes** contiene información sobre cada persona que ha realizado al menos una donación en DonorsChoose. Entre los datos disponibles se incluyen la ciudad, el estado, el código postal y si el donante es o no docente.
#
# ## <a id="2.1">2.1 Panorama General de los Donantes</a>
#
# A continuación, observaremos una vista previa de las primeras filas del conjunto de datos de los donantes para conocer su estructura y la información que contiene.

# %% [markdown]
# ### Descripción del código
#
# En este apartado se realizan algunas consultas básicas sobre el conjunto de datos de los donantes:
#
# - **Número total de registros** (`donors_df.shape`): muestra la cantidad de filas y columnas del conjunto de datos.
# - **Número de ciudades diferentes** (`len(donors_df['Donor City'].value_counts())`): calcula cuántas ciudades distintas aparecen registradas.
# - **Donantes con más de una donación**: cuenta cuántos donantes han realizado dos o más donaciones utilizando el identificador del donante (`Donor ID`).
# - **Vista previa del conjunto de datos** (`donors_df.head(3)`): muestra las primeras tres filas para conocer la estructura de la información.

# %% [markdown]
# Se tienen registrados **2,122,640 donantes** en DonorsChoose hasta **abril de 2018**. Estos donantes pertenecen a **15,204 ciudades diferentes** de Estados Unidos y de algunos otros países.
#
# De este gran número de donantes, únicamente **552,941 (aproximadamente el 26 %)** han realizado **más de una donación**.
#
# Uno de los principales objetivos del desafío **Data Science for Good** es descubrir patrones e información útil que permitan generar recomendaciones personalizadas para motivar a los donantes a contribuir nuevamente.
#
# Actualmente existen alrededor de **1,471,613 donantes** que solo han realizado **una única donación**, lo que representa una importante oportunidad para que DonorsChoose implemente estrategias que incentiven a estas personas a volver a donar.
#
# ---
#
# ## <a id="2.2">2.2 Donantes por Estado</a>
#
# ### <a id="2.2.1">2.2.1 Número de Donantes por Estado</a>

# %%
import folium
from folium import plugins
from io import StringIO
import folium 


statesll=StringIO("""State,Latitude,Longitude
Alabama,32.806671,-86.791130
Alaska,61.370716,-152.404419
Arizona,33.729759,-111.431221
Arkansas,34.969704,-92.373123
California,36.116203,-119.681564
Colorado,39.059811,-105.311104
Connecticut,41.597782,-72.755371
Delaware,39.318523,-75.507141
District of Columbia,38.897438,-77.026817
Florida,27.766279,-81.686783
Georgia,33.040619,-83.643074
Hawaii,21.094318,-157.498337
Idaho,44.240459,-114.478828
Illinois,40.349457,-88.986137
Indiana,39.849426,-86.258278
Iowa,42.011539,-93.210526
Kansas,38.526600,-96.726486
Kentucky,37.668140,-84.670067
Louisiana,31.169546,-91.867805
Maine,44.693947,-69.381927
Maryland,39.063946,-76.802101
Massachusetts,42.230171,-71.530106
Michigan,43.326618,-84.536095
Minnesota,45.694454,-93.900192
Mississippi,32.741646,-89.678696
Missouri,38.456085,-92.288368
Montana,46.921925,-110.454353
Nebraska,41.125370,-98.268082
Nevada,38.313515,-117.055374
New Hampshire,43.452492,-71.563896
New Jersey,40.298904,-74.521011
New Mexico,34.840515,-106.248482
New York,42.165726,-74.948051
North Carolina,35.630066,-79.806419
North Dakota,47.528912,-99.784012
Ohio,40.388783,-82.764915
Oklahoma,35.565342,-96.928917
Oregon,44.572021,-122.070938
Pennsylvania,40.590752,-77.209755
Rhode Island,41.680893,-71.511780
South Carolina,33.856892,-80.945007
South Dakota,44.299782,-99.438828
Tennessee,35.747845,-86.692345
Texas,31.054487,-97.563461
Utah,40.150032,-111.862434
Vermont,44.045876,-72.710686
Virginia,37.769337,-78.169968
Washington,47.400902,-121.490494
West Virginia,38.491226,-80.954453
Wisconsin,44.268543,-89.616508
Wyoming,42.755966,-107.302490""")

tempdf = states_df = donors_df['Donor State'].value_counts()
t1 = pd.DataFrame()
t1['Donor State'] = tempdf.index
t1['Donor Count'] = tempdf.values

# tempdf = combined_df.groupby(['Donor State']).agg({'Donation Amount':'sum'}).reset_index()
# t1 = tempdf.sort_values('Donation Amount', ascending=False)

sdf = pd.read_csv(statesll).rename(columns={'State':'Donor State'})
sdf = sdf.merge(t1, on='Donor State', how='inner')
sdf 

map4 = folium.Map(location=[39.50, -98.35], tiles='CartoDB dark_matter', zoom_start=3.5)
for j, rown in sdf.iterrows():
    rown = list(rown)
    folium.CircleMarker([float(rown[1]), float(rown[2])], popup="<b>State:</b>" + rown[0].title() +"<br> <b>Donors:</b> "+str(int(rown[3])), radius=float(rown[3])*0.0001, color='#be0eef', fill=True).add_to(map4)
map4
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import folium
#       2 from folium import plugins
#       3 from io import StringIO
#
# ModuleNotFoundError: No module named 'folium'

# %%
def bar_hor(df, col, title, color, w=None, h=None, lm=0, limit=100, return_trace=False, rev=False):
    cnt_srs = df[col].value_counts()
    yy = cnt_srs.head(limit).index[::-1] 
    xx = cnt_srs.head(limit).values[::-1] 
    if rev:
        yy = cnt_srs.tail(limit).index[::-1] 
        xx = cnt_srs.tail(limit).values[::-1] 
        
    
    trace = go.Bar(y=yy, x=xx, orientation = 'h', marker=dict(color=color))
    if return_trace:
        return trace 
    layout = dict(title=title, margin=dict(l=lm), width=w, height=h)
    data = [trace]
    fig = go.Figure(data=data, layout=layout)
    iplot(fig)

def bar_hor_noagg(x, y, title, color, w=None, h=None, lm=0, limit=100, rt=False):
    trace = go.Bar(y=x, x=y, orientation = 'h', marker=dict(color=color))
    if rt:
        return trace
    layout = dict(title=title, margin=dict(l=lm), width=w, height=h)
    data = [trace]
    fig = go.Figure(data=data, layout=layout)
    iplot(fig)


def bar_ver_noagg(x, y, title, color, w=None, h=None, lm=0, rt = False):
    trace = go.Bar(y=y, x=x, marker=dict(color=color))
    if rt:
        return trace
    layout = dict(title=title, margin=dict(l=lm), width=w, height=h)
    data = [trace]
    fig = go.Figure(data=data, layout=layout)
    iplot(fig)

    
trace1 = bar_hor(donors_df, 'Donor City', "Top Cities with maximum Donors", '#c2d2ed', 500, 400, 200, limit = 10, return_trace=True)
trace2 = bar_hor(donors_df, 'Donor State', "Top States with maximum Donors", '#c2d2ed', 500, 400, 200, limit = 10, return_trace=True)
trace4 = bar_hor(donors_df, 'Donor State', "Top States with maximum Donors", '#c2d2ed', 600, 400, 200, limit = 10, return_trace=True, rev=True)


fig = tools.make_subplots(rows=1, cols=2, print_grid=False, subplot_titles = ['States with maximum Donors','States with minimum Donors'])
# fig = tools.make_subplots(rows=2, cols=2, specs=[[{}, {}], [{'colspan': 2}, None]], print_grid=False, subplot_titles = ['States with maximum Donors','States with minimum Donors', 'Cities with maximum Donors'])
fig.append_trace(trace2, 1, 1);
fig.append_trace(trace4, 1, 2);
# fig.append_trace(trace1, 2, 1);

fig['layout'].update(height=400, showlegend=False);
iplot(fig);

# %%
> - California, siendo el estado con mayor población, también tiene una gran cantidad de donantes registrados con cerca de 300,000 donantes. **San Francisco y Los Angeles** son las principales ciudades de California donde se concentra la mayor parte de los donantes. El mayor número de escuelas y proyectos también proviene del estado de California.  
> - Nueva York, Texas y Florida, con aproximadamente 137,000, 134,000 y 108,000 donantes, son otros tres estados principales con una alta población de donantes. Las principales ciudades incluyen Nueva York, Miami, Tampa, Houston y Dallas, donde se concentra la mayor cantidad de donantes.  
> - Dakota del Norte, Dakota del Sur, Vermont y Wyoming son los estados con muy bajo número de donantes, menos de 4000. Existe una entrada llamada "others" en los datos de estados, que probablemente indica donantes docentes o donantes de otros países.  
> - Entre todas las ciudades de EE. UU., las tres principales son: **Chicago (aprox. 35K donantes), Nueva York (aprox. 27K donantes) y Brooklyn (aprox. 22K donantes)** con el mayor número de donantes. Las ciudades de California, San Francisco y Los Ángeles, son las siguientes con una gran base de donantes con aproximadamente 18K y 16K donantes respectivamente.  

## <a>Conjunto de datos ajustado por población</a>

Los principales estados en los gráficos anteriores son en realidad los estados con una población muy alta. Sería interesante encontrar el número de donantes por cada 100,000 personas en cada estado. He agregado un conjunto de datos ajustado por población que incluye la población de cada estado a partir de 2013.

Conjunto de datos de población: http://www.enchantedlearning.com/usa/states/population.shtml

## <a id="2.3">2.3 Estados con la mayor **relación de donantes a población**</a>
# Out:
#   Cell In[10], line 4
#     > - Entre todas las ciudades de EE. UU., las tres principales son: **Chicago (aprox. 35K donantes), Nueva York (aprox. 27K donantes) y Brooklyn (aprox. 22K donantes)** con el mayor número de donantes. Las ciudades de California, San Francisco y Los Ángeles, son las siguientes con una gran base de donantes con aproximadamente 18K y 16K donantes respectivamente.
#                                                                                           ^
# SyntaxError: invalid decimal literal
